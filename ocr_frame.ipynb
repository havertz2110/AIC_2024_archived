# %%
# EXTRACT FRAME
# create a folder to store extracted images
import os
folder = 'testfolder'
os.mkdir(folder)
# use opencv to do the job
import cv2
print(cv2.__version__)  # my version is 3.1.0
vidcap = cv2.VideoCapture('test.mp4')
count = 0
while True:
    success,image = vidcap.read()
    if not success:
        break
    cv2.imwrite(os.path.join(folder,"frame{:d}.jpg".format(count)), image)     # save frame as JPEG file
    count += 1
print("{} images are extacted in {}.".format(count,folder))
# Out:
# 4.10.0
# 0 images are extacted in testfolder.

# %%
# %pip install --upgrade google-cloud-vision
# Out:
# ...
#   Using cached google_cloud_vision-3.7.4-py2.py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached grpcio-1.66.1-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# ...
#   Using cached grpcio_status-1.66.1-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# ...
# Using cached google_cloud_vision-3.7.4-py2.py3-none-any.whl (467 kB)
# ...
# Using cached proto_plus-1.24.0-py3-none-any.whl (50 kB)
# Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
# Using cached grpcio-1.66.1-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached grpcio_status-1.66.1-py3-none-any.whl (14 kB)
# ...
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# ...

# %%
import cv2
import os
import json
from google.cloud import vision

# Set up the Google Cloud Vision API credentials
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'tranquil-wave-437007-h2-fda33506e3e1.json'
client = vision.ImageAnnotatorClient()

# List of directories to process
directories = [
    "D:\\AIC\\AIC_Keyframes\\L15_Keyframes\\L15_V028\\L15_V028_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L15_Keyframes\\L15_V029\\L15_V029_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L15_Keyframes\\L15_V030\\L15_V030_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L15_Keyframes\\L15_V031\\L15_V031_keyframes",

    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V001\\L16_V001_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V002\\L16_V002_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V003\\L16_V003_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V004\\L16_V004_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V005\\L16_V005_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V006\\L16_V006_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V007\\L16_V007_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V008\\L16_V008_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V009\\L16_V009_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V010\\L16_V010_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V011\\L16_V011_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V012\\L16_V012_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V013\\L16_V013_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V014\\L16_V014_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V015\\L16_V015_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V016\\L16_V016_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V017\\L16_V017_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V018\\L16_V018_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V019\\L16_V019_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V020\\L16_V020_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V021\\L16_V021_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V022\\L16_V022_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V023\\L16_V023_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V024\\L16_V024_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V025\\L16_V025_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V026\\L16_V026_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V027\\L16_V027_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V028\\L16_V028_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V029\\L16_V029_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L16_Keyframes\\L16_V030\\L16_V030_keyframes",

    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V001\\L17_V001_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V002\\L17_V002_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V003\\L17_V003_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V004\\L17_V004_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V005\\L17_V005_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V006\\L17_V006_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V007\\L17_V007_keyframes",  
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V009\\L17_V009_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V010\\L17_V010_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V011\\L17_V011_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V012\\L17_V012_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V013\\L17_V013_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V014\\L17_V014_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V015\\L17_V015_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V016\\L17_V016_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V017\\L17_V017_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V018\\L17_V018_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V019\\L17_V019_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V020\\L17_V020_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V021\\L17_V021_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V022\\L17_V022_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V023\\L17_V023_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V024\\L17_V024_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_V025\\L17_V025_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L17_Keyframes\\L17_
keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V002\\L22_V002_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V003\\L22_V003_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V004\\L22_V004_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V005\\L23_V005_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V006\\L22_V006_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V007\\L22_V007_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V008\\L22_V008_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V009\\L22_V009_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V010\\L22_V010_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V011\\L22_V011_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V012\\L22_V012_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V013\\L22_V013_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V014\\L22_V014_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V015\\L22_V015_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V016\\L22_V016_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V017\\L22_V017_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V018\\L22_V018_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V019\\L22_V019_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V020\\L22_V020_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V021\\L22_V021_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V022\\L22_V022_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V023\\L22_V023_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V024\\L22_V024_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V025\\L22_V025_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V026\\L22_V026_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V027\\L22_V027_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V028\\L22_V028_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V029\\L22_V029_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V030\\L22_V030_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L22_Keyframes\\L22_V031\\L22_V031_keyframes",

    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V001\\L23_V001_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V002\\L23_V002_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V003\\L23_V003_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V004\\L23_V004_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V005\\L23_V005_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V006\\L23_V006_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V007\\L23_V007_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V008\\L23_V008_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V009\\L23_V009_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V010\\L23_V010_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V011\\L23_V011_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V012\\L23_V012_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V013\\L23_V013_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V014\\L23_V014_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V015\\L23_V015_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V016\\L23_V016_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V017\\L23_V017_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V018\\L23_V018_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V019\\L23_V019_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V020\\L23_V020_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V021\\L23_V021_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V022\\L23_V022_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V023\\L23_V023_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V024\\L23_V024_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L23_Keyframes\\L23_V025\\L23_V025_keyframes",

    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V002\\L24_V002_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V003\\L24_V003_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V004\\L24_V004_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V005\\L24_V005_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V006\\L24_V006_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V007\\L24_V007_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V008\\L24_V008_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V009\\L24_V009_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V010\\L24_V010_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V011\\L24_V011_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V012\\L24_V012_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V013\\L24_V013_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V014\\L24_V014_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V015\\L24_V015_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V016\\L24_V016_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V017\\L24_V017_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V018\\L24_V018_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V019\\L24_V019_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V020\\L24_V020_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V021\\L24_V021_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V022\\L24_V022_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V023\\L24_V023_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V024\\L24_V024_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V025\\L24_V025_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V026\\L24_V026_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V027\\L24_V027_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V028\\L24_V028_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V029\\L24_V029_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V030\\L24_V030_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V031\\L24_V031_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V032\\L24_V032_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V033\\L24_V033_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V035\\L24_V035_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V036\\L24_V036_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V037\\L24_V037_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V038\\L24_V038_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V039\\L24_V039_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V040\\L24_V040_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V041\\L24_V041_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V042\\L24_V042_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V043\\L24_V043_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V044\\L24_V044_keyframes",
    "D:\\AIC\\AIC_Keyframes\\L24_Keyframes\\L24_V045\\L24_V045_keyframes"


]



# Function to process and save detected text from all frames using Google Cloud Vision API
def process_frames(directory, output_json_path):
    result_data = []

    # Iterate through each frame in the directory
    for filename in os.listdir(directory):
        if filename.endswith('.jpg') or filename.endswith('.png'):  # Add more extensions if needed
            image_path = os.path.join(directory, filename)

            # Read the image file as bytes
            with open(image_path, 'rb') as image_file:
                content = image_file.read()

            # Perform OCR on the image
            image = vision.Image(content=content)
            response = client.text_detection(image=image)
            texts = response.text_annotations

            img = cv2.imread(image_path)
            if img is None:
                print(f"Error loading image: {image_path}")
                continue

            if texts:
                # Only save the full detected text (the first element)
                full_text = texts[0].description

                # Remove newline characters (\n) from the detected text
                cleaned_text = full_text.replace('\n', ' ')

                # Create a dictionary to store the result data
                frame_data = {
                    'filename': os.path.basename(image_path),
                    'detected_texts': [{
                        'text': cleaned_text
                    }]
                }

                # Append the frame data to the results list
                result_data.append(frame_data)

    # Save the result data to a JSON file
    # Save the result data to a JSON file with UTF-8 encoding
    with open(output_json_path, 'w', encoding='utf-8') as json_file:
        json.dump(result_data, json_file, ensure_ascii=False, indent=4)
    print(f"Results saved to {output_json_path}")


# Iterate over each directory and process the frames
for directory in directories:
    # Define output JSON path based on the directory name
    dir_name = os.path.basename(os.path.dirname(directory))
    output_json_path = f'{dir_name}.json'
    
    # Run the function to process frames and save the results
    process_frames(directory, output_json_path)
# Out:
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# File c:\Users\buivu\anaconda3\envs\aic_env\Lib\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      75 try:
# ---> 76     return callable_(*args, **kwargs)
#      77 except grpc.RpcError as exc:
#
# File c:\Users\buivu\anaconda3\envs\aic_env\Lib\site-packages\grpc\_channel.py:1181, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1175 (
#    1176     state,
#    1177     call,
#    1178 ) = self._blocking(
#    1179     request, timeout, metadata, credentials, wait_for_ready, compression
#    1180 )
# -> 1181 return _end_unary_response_blocking(state, call, False, None)
#
# ...

# %%
# %pip install opencv-python
# Out:
# ...
#      ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/38.8 MB 1.1 MB/s eta 0:00:36
#      --------------------------------------- 0.1/38.8 MB 975.2 kB/s eta 0:00:40
#      ---------------------------------------- 0.2/38.8 MB 1.3 MB/s eta 0:00:30
#      ---------------------------------------- 0.2/38.8 MB 1.3 MB/s eta 0:00:30
#      ---------------------------------------- 0.4/38.8 MB 1.9 MB/s eta 0:00:21
#       --------------------------------------- 0.5/38.8 MB 1.9 MB/s eta 0:00:21
#       --------------------------------------- 0.6/38.8 MB 1.8 MB/s eta 0:00:21
#       --------------------------------------- 0.6/38.8 MB 1.9 MB/s eta 0:00:20
#       --------------------------------------- 0.6/38.8 MB 1.9 MB/s eta 0:00:20
#       --------------------------------------- 0.7/38.8 MB 1.6 MB/s eta 0:00:25
#       --------------------------------------- 0.7/38.8 MB 1.6 MB/s eta 0:00:25
# ...

# %%
import cv2
import os
import json
from google.cloud import vision

# Set up the Google Cloud Vision API credentials
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'ocrforaic1-432315-925a0ce77768.json'
client = vision.ImageAnnotatorClient()

# Define the path to the single image you want to process
image_path = 'dich-anh-viet-online.png'  # Replace with the actual path to your image

# Read the image file as bytes
with open(image_path, 'rb') as image_file:
    content = image_file.read()

# Perform OCR on the image
image = vision.Image(content=content)
response = client.text_detection(image=image)
texts = response.text_annotations

if texts:
    # Only save the full detected text (the first element)
    full_text = texts[0].description

    # Remove newline characters (\n) from the detected text
    cleaned_text = full_text.replace('\n', ' ')

    # Create a dictionary to store the result data
    result_data = {
        'filename': os.path.basename(image_path),
        'detected_texts': [{
            'text': cleaned_text
        }]
    }

    print(result_data)
else:
    print("No text detected in the image.")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
